# %% [markdown]
# # Aptitudes en Data Science
# <h3>Lo más importante</h3>
# <ul>
#     <li>Matemáticas</li>
#     <li>Python</li>
#     <li>SQL</li>
# </ul>
# <img src="image.png](attachment:image.png" alt="logo" width="200">
#
# <p>Otro tema muy importante es la <b>Estadística</b>.</p>
# <p>Si tienes dudas, puedes escribirnos <a href="mailto:ta_ds_online@thebridgeschool.es">ta_ds_online@thebridgeschool.es</a></p>
# <p>Y en esta web se aprende mucho sobre Machine Learning:<a href="https://www.kaggle.com/">Kaggle</a></p>
