# %% [markdown]
# <center>
#
# | Fundamentals | Data Analysis | Machine Learning | Data & Business |
# | :--- | :--- | :--- | :--- |
# |Jupyter | SQL | Supervisado | API |
# |GitHub | Estadistica | No supervisado | Depliegue |
# | Python | EDA | Deep Learning | Cloud Computing |
# <br>
#
# $$\sqrt{3x -1}+ (1+x)^2$$
#
# </center>
